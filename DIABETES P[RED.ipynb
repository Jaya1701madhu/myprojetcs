# %%
import pandas as pd
data=pd.read_csv('diabetess.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
import pandas as pd
data=pd.read_csv('diabetess.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#  reading last 5 rows
data.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
# shape of the data
data.shape
# Out:
# (768, 9)

# %%
# getting information about
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
import numpy as np
dc=data.copy(deep=True)
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
dc[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI']]=dc[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI']].replace(0,np.nan)

# %%
dc.isnull().sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
data['Pregnancies']=data['Pregnancies'].replace(0,data['Pregnancies'].mean())
data['Glucose']=data['Glucose'].replace(0,data['Glucose'].mean())
data['BloodPressure']=data['BloodPressure'].replace(0,data['BloodPressure'].mean())
data['SkinThickness']=data['SkinThickness'].replace(0,data['SkinThickness'].mean())
data['Insulin']=data['Insulin'].replace(0,data['Insulin'].mean())
data['BMI']=data['BMI'].replace(0,data['BMI'].mean())

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# STORE FEATURE MATRIX IN X AND RESPOSE TSRGET Y IN VRCTOR Y
x=data.drop('Outcome',axis=1)
y=data['Outcome']

# %%
# splitting thwe data set into the training set and test darta
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.linear_model import LogisticRegression

from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(max_depth=3)
rf.fit(x,y)
# Out:
# RandomForestClassifier(max_depth=3)

# %%
import joblib
joblib.dump(rf,'model_joblib_diabetes')
# Out:
# ['model_joblib_diabetes']

# %%
# PREDICTION ON NEW DATA

# %%
import pandas as pd
new_data=pd.DataFrame({'Pregnancies':6,
                       'Glucose':148.0,
                      'BloodPressure':72.0,
                       'SkinThickness':35.0,
                       'Insulin':79.74,
                       'BMI':33.6,
                       'DiabetesPedigreeFunction':0.627,
                      'Age':50},index=[0])

# %%
k=rf.predict(new_data)
k
# Out:
# array([1], dtype=int64)

# %%
if k==0:
    print("non diabeteic")
else:
    print("diabetic")
# Out:
# diabetic

# %%
# GUI

# %%
import tkinter
import joblib

# %%
from tkinter import *
import joblib
from sklearn import *

# %%
rf=RandomForestClassifier(max_depth=3)
rf.fit(x,y)
joblib.dump(rf,'model_joblib_diabetes')
from PIL import ImageTk,Image
import PIL.Image
import tkinter
import joblib

from tkinter import *
import joblib
from sklearn import *

def Seee():
    p1=float(e1.get())
    p2=float(e2.get())
    p3=float(e3.get())
    p4=float(e4.get())
    p5=float(e5.get())
    p6=float(e6.get())
    p7=float(e7.get())
    p8=float(e8.get())
    
    model=joblib.load('model_joblib_diabetes')
    
    r=model.predict([[p1,p2,p3,p4,p5,p6,p7,p8]])
    
    if r==0:
        lb1=Label(text="congrats the person is non diabetic",font=('Arial',30,'bold')).grid(row=33)
        lb1.grid( )
    else:
        Label(text='Sorry the person is diabetic visit hospital',font=('Arial',30,'bold')).grid(row=31)
    
master=Tk()


master.title('diabetes prediction using ML')
master.configure(bg='navyblue')
master.maxsize(1500,1500)

label=Label(master,text='diabetes prediction using ml',bg='blue',fg='white').grid(row=0,column=7,pady=50)


Label(master,text='Pregnancies').grid(row=1,column=3,pady=2)

Label(master,text='Glucose').grid(row=2,column=3,pady=2)

Label(master,text='ENTER THE BloodPressure').grid(row=3,column=3,pady=2)

Label(master,text=' ENTER THE SkinThickness').grid(row=4,column=3,pady=2)

Label(master,text='ENTER THE Insulin',).grid(row=5,column=3,pady=2)

Label(master,text=' ENTER BMI').grid(row=6,column=3,pady=2)

Label(master,text=' ENTER VALUE OF DIABETES PEDEDEGREEFUCTION').grid(row=7,column=3,pady=2)

Label(master,text=' ENTER AGE').grid(row=8,column=3,pady=2)

e1=Entry(bg='cyan',fg='black')
e2=Entry(bg='cyan',fg='black')
e3=Entry(bg='cyan',fg='black')
e4=Entry(bg='cyan',fg='black')
e5=Entry(bg='cyan',fg='black')
e6=Entry(bg='cyan',fg='black')
e7=Entry(bg='cyan',fg='black')
e8=Entry(bg='cyan',fg='black')
e1.grid(row=1, column=7)
e2.grid(row=2, column=7)
e3.grid(row=3, column=7)
e4.grid(row=4, column=7)
e5.grid(row=5, column=7)
e6.grid(row=6, column=7)
e7.grid(row=7, column=7)
e8.grid(row=8, column=7)




BTN=Button(text='predict',bg='green',activebackground='blue',borderwidth=3,font=('Arial',15,'bold'),command=Seee)
BTN.grid(row=13,column=20,pady=40)
master.mainloop()
